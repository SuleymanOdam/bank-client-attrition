# %%
import streamlit as st
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
st.set_page_config(page_title="Bank_churners",page_icon=':chart:')
st.title(':chart: Sample Dashboard Bank_churners')
st.markdown(
    """
    <style>
    body {
        background-image: url("D:\Sulaymon\ transparent-png.png");
        background-size: cover;
    }
    </style>
    """,
    unsafe_allow_html=True
)
fl = st.file_uploader(":file_folder: Upload a file ",type=(['csv','txt','xlsx','xls']))
if fl is not None:
    filename = fl.name
    st.write(filename)
    df = pd.read_csv(filename,encoding='utf-8')
else :
    os.chdir(r"c:\Users\user\Downloads")
    df = pd.read_csv("bankchurners.csv",encoding='utf-8')

# Отображение данных
st.write("Просмотр данных:")
st.write(df)
# Добавление графика
st.write("График распределения отток:")
hist_values = np.histogram(df['avg_open_to_buy'], bins=20, range=(0, 100))[0]
st.bar_chart(hist_values)

fig, ax = plt.subplots()
ax.pie(df['months_inactive_12_mon'], labels=df['contacts_count_12_mon'], autopct='%1.1f%%', startangle=90)
ax.axis('equal')
# Out:
# 2024-03-21 22:23:46.698
# ...
#   command:
#
#     streamlit run C:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# (-1.1, 1.1, -1.1, 1.1)
